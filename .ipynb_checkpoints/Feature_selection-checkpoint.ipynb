# %%
import pandas as pd
import numpy as np
import scipy as sp
import glob
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from sklearn import svm
import seaborn as sns
# from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.grid_search import GridSearchCV
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

pd.set_option('display.max_columns', 500)

path ='full_features'
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0, encoding='iso-8859-1')
    list_.append(df)
df = pd.concat(list_)
df
# Out:
# /Users/Yomancool/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/Yomancool/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
#       Unnamed: 0  popularity                 song_id               artist_id  \
# 0              0          95  1OmcAT5Y8eg5bUPv9qJT4R  246dkjvS1zLTtiykXe5h60
# 1              1          87  42CeaId2XNlxugDvyqHfDf  246dkjvS1zLTtiykXe5h60
# 2              2          77  4wdZdkEugVVorAfzqRqC6N  246dkjvS1zLTtiykXe5h60
# 3              3          54  2PDoD69oMLWdi3iPGjN2DW  4O15NlyKLIASxsJ0PrXPfz
# 4              4          55  2rt6EWKD5iCod4cmWCCQKG  50co4Is1HCEo8bhOyUWKpn
# 5              5          61  53dUsHPehH9DtFMpoFE146  21WS9wngs9AqFckK7yYJPM
# 6              6          50  57pTGa2YCwFT9pBIsIVO3z  6icQOAFXDZKsumw3YXyusw
# 7              7          52  2fEG34NYIZ33WTxhDFePvp  1gPhS1zisyXr5dHTYZyiMe
# 8              8          58  6oa0iUWXuBhCJ419Tm0RKV  1JPy5PsJtkhftfdr6saN2i
# 9              9          66  2YK01AIIWuywG24gsbuizE  246dkjvS1zLTtiykXe5h60
# 10            10          59  29VZKgZvAjFRxxBnctjqOn  246dkjvS1zLTtiykXe5h60
# 11            11         100  0ofbQMrRDsUaVKq2mGLEAb  4nDoRrQiYLoBzwC5BhVJzF
# 12            12          87  3whrwq4DtvucphBPUogRuJ  4nDoRrQiYLoBzwC5BhVJzF
# 13            13          83  4xBjsLUSjcx2h7PcRikpQp  4nDoRrQiYLoBzwC5BhVJzF
# 14            14          83  1SJtlNRJDeYHioymcvsqev  4nDoRrQiYLoBzwC5BhVJzF
# 15            15          63  6VpQdig9pdpTSIFItgkJV5  4nDoRrQiYLoBzwC5BhVJzF
# 16            16          63  4V6MRo0CEAC9MwAm7dkPuL  4nDoRrQiYLoBzwC5BhVJzF
# 17            17          50  0BlY60NrN0fFWbdW3RW40q  4nDoRrQiYLoBzwC5BhVJzF
# 18            18          78  3NgCzSW98SsqBdpYcnm4kv  4nDoRrQiYLoBzwC5BhVJzF
# 19            19          92  2fQrGHiQOvpL9UgPvtYy6G  1URnnhqYAYcrqrcwql10ft
# 20            20          78  1vc2YF7ZvUtwr45HNpdGch  1URnnhqYAYcrqrcwql10ft
# 21            21          73  55GLc4nywcX4aIlOcx1u06  1URnnhqYAYcrqrcwql10ft
# 22            22          71  6g0TAJ1grweRwBMLQyiZFb  1URnnhqYAYcrqrcwql10ft
# 23            23          71  2aNdXtCtyoB2KrUh7pJYxO  1URnnhqYAYcrqrcwql10ft
# 24            24          70  1szcZMcUlPjCItP4xNIU3E  1URnnhqYAYcrqrcwql10ft
# 25            25          70  5ZIZgRrrDj60O0F5oA9bVz  1URnnhqYAYcrqrcwql10ft
# 26            26          68  5aZrmUOr1kL5U6cg0WZNyw  1URnnhqYAYcrqrcwql10ft
# 14              Camila Cabello                           Crying in the Club
# 15              Camila Cabello                            Never Be the Same
# 16              Camila Cabello                                 Real Friends
# 17              Camila Cabello               Never Be the Same (Radio Edit)
# 18              Camila Cabello                             I Have Questions
# 19                   21 Savage                                   Issa Album
# 20                   21 Savage                                   Issa Album
# 21                   21 Savage                                   Issa Album
# 22                   21 Savage                                   Issa Album
# 23                   21 Savage                                   Issa Album
# 24                   21 Savage                                   Issa Album
# 25                   21 Savage                                   Issa Album
# 26                   21 Savage                                   Issa Album
# 27                   21 Savage                                   Issa Album
# 28                   21 Savage                                   Issa Album
# 29                   21 Savage                                   Issa Album
# ...                        ...                                          ...
# 9970              Grace Carter                                      Silence
# 9971               El Ezequiel                              Chico Enamorado
# 9972                       AOA                  AOA 1st Album ANGEL'S KNOCK
# 9973          Arsenal Efectivo                                   En La Fuga
# 9974               Eric Church                   61 Days In Church Volume 3
# 9975                 Ivy Queen                               ?mame o M?tame
# 9976             Jaws of Love.                Tasha Sits Close to the Piano
# 9977                    BLAISE                                          Dua
# 9978            Thomas Sanders                  The Things We Used to Share
# 9979             Mayday Parade  A Lesson In Romantics (Anniversary Edition)
# 9980          Christian French                                    love ride
# 9981            Cloud Nothings                           Life Without Sound
# 9982        The Underachievers                                  Renaissance
# 9983             Billy Raffoul                                       Driver
# 9984               David Bowie     A New Career In A New Town (1977 - 1982)
# 9985                   Fonseca                          Por Pura Curiosidad
# 9986      Charlotte Day Wilson                                        Doubt
# 9987             Daniel Schulz                               Turn Back Time
# 9988               Sunni Colon                                Little Things
# 9989                 GRiZMATiK                                As We Proceed
# 9990  Dimitri Vangelis & Wyman                                       Legacy
# 9991                     Hanzo                         radio.wavs//volume.4
# 9992               Alicia Keys                        Vault Playlist Vol. 1
# 9993                    Mokita                                      Goodbye
# 9994            Daniella Mason                              Cover the Earth
# 9995              Laura Hanson                        Puff The Magic Dragon
# 9996                 KAZZANOVA                           Everybody Hands Up
# 9997                       PAZ                                     Taco Bae
# 9998              Dizzy Wright                             The Golden Age 2
# 9999                       BLR                                    EP Part 1
#
#      explicit  disc_number  track_number  \
# 0        True            1             1
# 1        True            1             1
# 2        True            1             8
# 3       False            1             2
# 4        True            1             1
# 5        True            1             4
# 6       False            1            10
# 7        True            1             9
# 8       False            1             7
# 9        True            1             1
# 10      False            1             1
# 11      False            1             1
# 12      False            1             1
# 13      False            1             1
# 14      False            1             1
# 15      False            1             1
# 16      False            1             1
# 17      False            1             1
# 18      False            1             1
# 19       True            1             1
# 20       True            1             2
# 21       True            1             3
# 22       True            1            10
# 23       True            1             5
# 24       True            1            14
# 25       True            1             4
# 26       True            1            12
# 27       True            1             6
# 28       True            1             8
# 29       True            1            11
# ...       ...          ...           ...
# 9970    False            1             1
# 9971    False            1             1
# 9972    False            1             1
# 9973    False            1             9
# 9974    False            1             7
# 9975    False            1             1
# 9976    False            1             2
# 9977     True            1             1
# 9978    False            1             1
# 9979    False            1             1
# 9980    False            1             1
# 9981    False            1             5
# 9982     True            1             5
# 9983    False            1             1
# 9984    False            9            19
# 9985    False            1             1
# 9986    False            1             1
# 9987    False            1             1
# 9988     True            1             1
# 9989    False            1             1
# 9990    False            1             1
# 9991    False            1             5
# 9992    False            1             1
# 9993    False            1             1
# 9994    False            1             1
# 9995    False            1             1
# 9996    False            1             1
# 9997    False            1             1
# 9998     True            1             1
# 9999    False            1             1
#
#                                        uri    tempo            type   key  \
# 0     spotify:track:1OmcAT5Y8eg5bUPv9qJT4R  159.786  audio_features   5.0
# 1     spotify:track:42CeaId2XNlxugDvyqHfDf   90.013  audio_features   4.0
# 2     spotify:track:4wdZdkEugVVorAfzqRqC6N  180.008  audio_features   4.0
# 3                                      NaN      NaN             NaN   NaN
# 4                                      NaN      NaN             NaN   NaN
# 5     spotify:track:53dUsHPehH9DtFMpoFE146  149.906  audio_features   6.0
# 6     spotify:track:57pTGa2YCwFT9pBIsIVO3z  146.002  audio_features   1.0
# 7     spotify:track:2fEG34NYIZ33WTxhDFePvp  173.033  audio_features   1.0
# 8                                      NaN      NaN             NaN   NaN
# 9                                      NaN      NaN             NaN   NaN
# 10    spotify:track:29VZKgZvAjFRxxBnctjqOn  159.706  audio_features   5.0
# 11    spotify:track:0ofbQMrRDsUaVKq2mGLEAb  104.992  audio_features   7.0
# 12    spotify:track:3whrwq4DtvucphBPUogRuJ  105.031  audio_features   2.0
# 13    spotify:track:4xBjsLUSjcx2h7PcRikpQp  139.953  audio_features   5.0
# 14    spotify:track:1SJtlNRJDeYHioymcvsqev   85.227  audio_features   6.0
# 15    spotify:track:6VpQdig9pdpTSIFItgkJV5  129.961  audio_features   0.0
# 16    spotify:track:4V6MRo0CEAC9MwAm7dkPuL   91.958  audio_features   3.0
# 17    spotify:track:0BlY60NrN0fFWbdW3RW40q  129.942  audio_features   0.0
# 18    spotify:track:3NgCzSW98SsqBdpYcnm4kv  167.999  audio_features  10.0
# 19    spotify:track:2fQrGHiQOvpL9UgPvtYy6G   75.016  audio_features   8.0
# 20    spotify:track:1vc2YF7ZvUtwr45HNpdGch   82.008  audio_features   5.0
# 21    spotify:track:55GLc4nywcX4aIlOcx1u06   93.024  audio_features  10.0
# 22    spotify:track:6g0TAJ1grweRwBMLQyiZFb  173.986  audio_features   9.0
# 23    spotify:track:2aNdXtCtyoB2KrUh7pJYxO  123.020  audio_features   6.0
# 24    spotify:track:1szcZMcUlPjCItP4xNIU3E  150.004  audio_features   0.0
# 25    spotify:track:5ZIZgRrrDj60O0F5oA9bVz  158.050  audio_features   6.0
# 26    spotify:track:5aZrmUOr1kL5U6cg0WZNyw  155.029  audio_features   1.0
# 27                                     NaN      NaN             NaN   NaN
# 28                                     NaN      NaN             NaN   NaN
# 29    spotify:track:74BIr8H03lr5L6LZ1friIa  158.923  audio_features   5.0
# ...                                    ...      ...             ...   ...
# 9970                                   NaN      NaN             NaN   NaN
# 9971                                   NaN      NaN             NaN   NaN
# 9972                                   NaN      NaN             NaN   NaN
# 9973                                   NaN      NaN             NaN   NaN
# 9974                                   NaN      NaN             NaN   NaN
# 9975                                   NaN      NaN             NaN   NaN
# 9976                                   NaN      NaN             NaN   NaN
# 9977                                   NaN      NaN             NaN   NaN
# 9978                                   NaN      NaN             NaN   NaN
# 9979                                   NaN      NaN             NaN   NaN
# 9980                                   NaN      NaN             NaN   NaN
# 9981                                   NaN      NaN             NaN   NaN
# 9982                                   NaN      NaN             NaN   NaN
# 9983                                   NaN      NaN             NaN   NaN
# 9984                                   NaN      NaN             NaN   NaN
# 9985                                   NaN      NaN             NaN   NaN
# 9986                                   NaN      NaN             NaN   NaN
# 9987                                   NaN      NaN             NaN   NaN
# 9988  spotify:track:0N0ZPAQXozVq5FXIj2Cugl   92.987  audio_features  10.0
# 9989  spotify:track:3anOLstTVypgnV5yVNLmc7  109.946  audio_features   1.0
# 9990  spotify:track:18xIe4yCyqSr4WoLbM03t8  127.978  audio_features   4.0
# 9991  spotify:track:7rX35uKqAa5tAl6waFWLVJ  168.576  audio_features   1.0
# 9992  spotify:track:2VFf8YhTnmhWF108o9UEr7   89.798  audio_features   4.0
# 9993  spotify:track:4N6Wow2t6KO9WzpE4x59Kt   82.961  audio_features  10.0
# 9994  spotify:track:6zgQZYEJ7ZIakzla5SGI7H  141.576  audio_features   1.0
# 9995  spotify:track:78RskfTZHN7IYXY1ZxNbKY  114.703  audio_features   0.0
# 9996  spotify:track:0lYcpVd3kVv7qHF86kdYIw  130.003  audio_features   5.0
# 9997  spotify:track:7AcKIf5gdCkmIRQx42McOy  125.967  audio_features   9.0
# 9998  spotify:track:2dH2t9LZsMMTxn5fOcQ4tp   88.939  audio_features   1.0
# 9999  spotify:track:52YQPzxd3ImQ2kpD14gMua  124.005  audio_features   8.0
#
#       loudness  mode  speechiness  liveness  valence  danceability  energy  \
# 0       -6.631   0.0       0.0776    0.1430    0.141         0.580  0.5310
# 1       -5.566   1.0       0.0841    0.0734    0.434         0.765  0.6880
# 2       -5.468   1.0       0.1580    0.0810    0.428         0.672  0.6840
# 3          NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 4          NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 5       -3.885   1.0       0.0539    0.3400    0.495         0.703  0.6610
# 6       -6.454   1.0       0.0759    0.0890    0.641         0.780  0.4750
# 7       -6.684   1.0       0.2760    0.1710    0.838         0.544  0.8090
# 8          NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9          NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 10      -6.759   0.0       0.1450    0.1430    0.141         0.552  0.5030
# 11      -4.323   0.0       0.0312    0.1040    0.418         0.768  0.5170
# 12      -4.036   1.0       0.0321    0.1330    0.349         0.751  0.5790
# 13      -6.735   0.0       0.0536    0.1320    0.167         0.655  0.5760
# 14      -5.834   0.0       0.3830    0.1630    0.603         0.334  0.6170
# 15      -4.343   1.0       0.0733    0.1150    0.264         0.643  0.7090
# 16      -8.612   1.0       0.1170    0.0782    0.819         0.740  0.3030
# 17      -4.380   1.0       0.0788    0.1210    0.269         0.652  0.6820
# 18      -6.096   0.0       0.2760    0.1050    0.220         0.393  0.5550
# 19      -8.228   0.0       0.3510    0.0871    0.376         0.884  0.3460
# 20     -11.344   0.0       0.2850    0.1310    0.464         0.839  0.4370
# 21     -11.115   1.0       0.3060    0.1070    0.383         0.701  0.6240
# 22      -9.652   0.0       0.4340    0.0508    0.646         0.779  0.5970
# 23      -9.790   0.0       0.2450    0.1150    0.223         0.916  0.5370
# 24     -10.354   0.0       0.4010    0.0891    0.190         0.743  0.4670
# 25      -9.729   0.0       0.3730    0.0854    0.387         0.856  0.5400
# 26      -9.028   1.0       0.2590    0.1260    0.274         0.844  0.4540
# 27         NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 28         NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 29     -11.666   0.0       0.3430    0.1150    0.211         0.835  0.5210
# ...        ...   ...          ...       ...      ...           ...     ...
# 9970       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9971       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9972       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9973       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9974       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9975       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9976       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9977       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9978       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9979       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9980       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9981       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9982       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9983       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9984       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9985       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9986       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9987       NaN   NaN          NaN       NaN      NaN           NaN     NaN
# 9988    -9.168   0.0       0.0633    0.1620    0.846         0.772  0.6970
# 9989    -2.974   1.0       0.0636    0.0927    0.418         0.610  0.8300
# 9990    -4.439   0.0       0.0375    0.4470    0.197         0.587  0.7720
# 9991   -13.502   1.0       0.4860    0.1100    0.489         0.578  0.3790
# 9992    -5.862   1.0       0.0331    0.0997    0.433         0.379  0.3250
# 9993    -7.593   1.0       0.0413    0.1640    0.164         0.597  0.4550
# 9994    -4.526   0.0       0.0400    0.3840    0.316         0.425  0.8060
# 9995   -23.420   1.0       0.0545    0.1220    0.474         0.555  0.0306
# 9996    -1.908   0.0       0.0432    0.0810    0.361         0.576  0.9410
# 9997    -3.083   0.0       0.1720    0.0504    0.649         0.884  0.9550
# 9998    -6.906   0.0       0.2390    0.2260    0.339         0.678  0.5850
# 9999    -5.068   1.0       0.1200    0.1680    0.137         0.864  0.7380
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1OmcAT5Y8eg5...
# 1     https://api.spotify.com/v1/tracks/42CeaId2XNlx...
# 2     https://api.spotify.com/v1/tracks/4wdZdkEugVVo...
# 3                                                   NaN
# 4                                                   NaN
# 5     https://api.spotify.com/v1/tracks/53dUsHPehH9D...
# 6     https://api.spotify.com/v1/tracks/57pTGa2YCwFT...
# 7     https://api.spotify.com/v1/tracks/2fEG34NYIZ33...
# 8                                                   NaN
# 9                                                   NaN
# 10    https://api.spotify.com/v1/tracks/29VZKgZvAjFR...
# 11    https://api.spotify.com/v1/tracks/0ofbQMrRDsUa...
# 12    https://api.spotify.com/v1/tracks/3whrwq4Dtvuc...
# 13    https://api.spotify.com/v1/tracks/4xBjsLUSjcx2...
# 14    https://api.spotify.com/v1/tracks/1SJtlNRJDeYH...
# 15    https://api.spotify.com/v1/tracks/6VpQdig9pdpT...
# 16    https://api.spotify.com/v1/tracks/4V6MRo0CEAC9...
# 17    https://api.spotify.com/v1/tracks/0BlY60NrN0fF...
# 18    https://api.spotify.com/v1/tracks/3NgCzSW98Ssq...
# 19    https://api.spotify.com/v1/tracks/2fQrGHiQOvpL...
# 20    https://api.spotify.com/v1/tracks/1vc2YF7ZvUtw...
# 21    https://api.spotify.com/v1/tracks/55GLc4nywcX4...
# 22    https://api.spotify.com/v1/tracks/6g0TAJ1grweR...
# 23    https://api.spotify.com/v1/tracks/2aNdXtCtyoB2...
# 24    https://api.spotify.com/v1/tracks/1szcZMcUlPjC...
# 25    https://api.spotify.com/v1/tracks/5ZIZgRrrDj60...
# 26    https://api.spotify.com/v1/tracks/5aZrmUOr1kL5...
# 27                                                  NaN
# 28                                                  NaN
# 29    https://api.spotify.com/v1/tracks/74BIr8H03lr5...
# ...                                                 ...
# 9970                                                NaN
# 9971                                                NaN
# 9972                                                NaN
# 9973                                                NaN
# 9974                                                NaN
# 9975                                                NaN
# 9976                                                NaN
# 9977                                                NaN
# 9978                                                NaN
# 9979                                                NaN
# 9980                                                NaN
# 9981                                                NaN
# 9982                                                NaN
# 9983                                                NaN
# 9984                                                NaN
# 9985                                                NaN
# 9986                                                NaN
# 9987                                                NaN
# 9988  https://api.spotify.com/v1/tracks/0N0ZPAQXozVq...
# 9989  https://api.spotify.com/v1/tracks/3anOLstTVypg...
# 9990  https://api.spotify.com/v1/tracks/18xIe4yCyqSr...
# 9991  https://api.spotify.com/v1/tracks/7rX35uKqAa5t...
# 9992  https://api.spotify.com/v1/tracks/2VFf8YhTnmhW...
# 9993  https://api.spotify.com/v1/tracks/4N6Wow2t6KO9...
# 9994  https://api.spotify.com/v1/tracks/6zgQZYEJ7ZIa...
# 9995  https://api.spotify.com/v1/tracks/78RskfTZHN7I...
# 9996  https://api.spotify.com/v1/tracks/0lYcpVd3kVv7...
# 9997  https://api.spotify.com/v1/tracks/7AcKIf5gdCkm...
# 9998  https://api.spotify.com/v1/tracks/2dH2t9LZsMMT...
# 9999  https://api.spotify.com/v1/tracks/52YQPzxd3ImQ...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1Omc...     218320.0
# 1     https://api.spotify.com/v1/audio-analysis/42Ce...     229573.0
# 2     https://api.spotify.com/v1/audio-analysis/4wdZ...     229053.0
# 3                                                   NaN          NaN
# 4                                                   NaN          NaN
# 5     https://api.spotify.com/v1/audio-analysis/53dU...     249240.0
# 6     https://api.spotify.com/v1/audio-analysis/57pT...     202093.0
# 7     https://api.spotify.com/v1/audio-analysis/2fEG...     192280.0
# 8                                                   NaN          NaN
# 9                                                   NaN          NaN
# 10    https://api.spotify.com/v1/audio-analysis/29VZ...     218480.0
# 11    https://api.spotify.com/v1/audio-analysis/0ofb...     216897.0
# 12    https://api.spotify.com/v1/audio-analysis/3whr...     199095.0
# 13    https://api.spotify.com/v1/audio-analysis/4xBj...     228893.0
# 14    https://api.spotify.com/v1/audio-analysis/1SJt...     216391.0
# 15    https://api.spotify.com/v1/audio-analysis/6VpQ...     227088.0
# 16    https://api.spotify.com/v1/audio-analysis/4V6M...     213933.0
# 17    https://api.spotify.com/v1/audio-analysis/0BlY...     227077.0
# 18    https://api.spotify.com/v1/audio-analysis/3NgC...     221881.0
# 19    https://api.spotify.com/v1/audio-analysis/2fQr...     220307.0
# 20    https://api.spotify.com/v1/audio-analysis/1vc2...     271307.0
# 21    https://api.spotify.com/v1/audio-analysis/55GL...     239160.0
# 22    https://api.spotify.com/v1/audio-analysis/6g0T...     234280.0
# 23    https://api.spotify.com/v1/audio-analysis/2aNd...     313987.0
# 24    https://api.spotify.com/v1/audio-analysis/1szc...     219360.0
# 25    https://api.spotify.com/v1/audio-analysis/5ZIZ...     162253.0
# 26    https://api.spotify.com/v1/audio-analysis/5aZr...     431587.0
# 27                                                  NaN          NaN
# 28                                                  NaN          NaN
# 29    https://api.spotify.com/v1/audio-analysis/74BI...     147427.0
# ...                                                 ...          ...
# 9970                                                NaN          NaN
# 9971                                                NaN          NaN
# 9972                                                NaN          NaN
# 9973                                                NaN          NaN
# 9974                                                NaN          NaN
# 9975                                                NaN          NaN
# 9976                                                NaN          NaN
# 9977                                                NaN          NaN
# 9978                                                NaN          NaN
# 9979                                                NaN          NaN
# 9980                                                NaN          NaN
# 9981                                                NaN          NaN
# 9982                                                NaN          NaN
# 9983                                                NaN          NaN
# 9984                                                NaN          NaN
# 9985                                                NaN          NaN
# 9986                                                NaN          NaN
# 9987                                                NaN          NaN
# 9988  https://api.spotify.com/v1/audio-analysis/0N0Z...     240617.0
# 9989  https://api.spotify.com/v1/audio-analysis/3anO...     260069.0
# 9990  https://api.spotify.com/v1/audio-analysis/18xI...     198426.0
# 9991  https://api.spotify.com/v1/audio-analysis/7rX3...      74501.0
# 9992  https://api.spotify.com/v1/audio-analysis/2VFf...     259570.0
# 9993  https://api.spotify.com/v1/audio-analysis/4N6W...     214053.0
# 9994  https://api.spotify.com/v1/audio-analysis/6zgQ...     210698.0
# 9995  https://api.spotify.com/v1/audio-analysis/78Rs...      76779.0
# 9996  https://api.spotify.com/v1/audio-analysis/0lYc...     324125.0
# 9997  https://api.spotify.com/v1/audio-analysis/7AcK...     249524.0
# 9998  https://api.spotify.com/v1/audio-analysis/2dH2...     207640.0
# 9999  https://api.spotify.com/v1/audio-analysis/52YQ...     219194.0
#
#       time_signature  acousticness  instrumentalness  \
# 0                4.0      0.128000          0.000127
# 1                4.0      0.633000          0.000000
# 2                4.0      0.604000          0.000000
# 3                NaN           NaN               NaN
# 4                NaN           NaN               NaN
# 5                4.0      0.051700          0.000000
# 6                4.0      0.036100          0.000000
# 7                4.0      0.423000          0.000000
# 8                NaN           NaN               NaN
# 9                NaN           NaN               NaN
# 10               4.0      0.138000          0.000555
# 11               4.0      0.186000          0.000038
# 12               4.0      0.398000          0.000023
# 13               4.0      0.029500          0.115000
# 14               4.0      0.334000          0.000000
# 15               4.0      0.145000          0.000449
# 16               4.0      0.835000          0.000000
# 17               4.0      0.156000          0.000130
# 18               4.0      0.405000          0.000000
# 19               4.0      0.015100          0.000007
# 20               4.0      0.043800          0.000003
# 21               4.0      0.219000          0.000000
# 22               4.0      0.723000          0.000045
# 23               4.0      0.188000          0.002860
# 24               4.0      0.145000          0.000001
# 25               4.0      0.000985          0.000016
# 26               4.0      0.072300          0.787000
# 27               NaN           NaN               NaN
# 28               NaN           NaN               NaN
# 29               4.0      0.297000          0.000458
# ...              ...           ...               ...
# 9970             NaN           NaN               NaN
# 9971             NaN           NaN               NaN
# 9972             NaN           NaN               NaN
# 9973             NaN           NaN               NaN
# 9974             NaN           NaN               NaN
# 9975             NaN           NaN               NaN
# 9976             NaN           NaN               NaN
# 9977             NaN           NaN               NaN
# 9978             NaN           NaN               NaN
# 9979             NaN           NaN               NaN
# 9980             NaN           NaN               NaN
# 9981             NaN           NaN               NaN
# 9982             NaN           NaN               NaN
# 9983             NaN           NaN               NaN
# 9984             NaN           NaN               NaN
# 9985             NaN           NaN               NaN
# 9986             NaN           NaN               NaN
# 9987             NaN           NaN               NaN
# 9988             4.0      0.302000          0.000000
# 9989             4.0      0.016800          0.011900
# 9990             4.0      0.021400          0.698000
# 9991             4.0      0.843000          0.916000
# 9992             4.0      0.712000          0.000000
# 9993             4.0      0.079500          0.000000
# 9994             4.0      0.005960          0.000130
# 9995             4.0      0.995000          0.958000
# 9996             4.0      0.000098          0.741000
# 9997             4.0      0.003410          0.187000
# 9998             4.0      0.050000          0.000000
# 9999             4.0      0.101000          0.854000
#
#                                           artist_genres  artist_popularity  \
# 0                                    ['pop rap', 'rap']                 99
# 1                                    ['pop rap', 'rap']                 99
# 2                                    ['pop rap', 'rap']                 99
# 3                                               ['rap']                 95
# 4     ['dwn trap', 'gangster rap', 'pop rap', 'rap',...                 95
# 5     ['dwn trap', 'pop rap', 'rap', 'southern hip h...                 86
# 6          ['dwn trap', 'pop rap', 'rap', 'trap music']                 88
# 7     ['deep southern trap', 'dwn trap', 'pop rap', ...                 82
# 8     ['bass trap', 'breakbeat', 'brostep', 'edm', '...                 70
# 9                                    ['pop rap', 'rap']                 99
# 10                                   ['pop rap', 'rap']                 99
# 11                ['dance pop', 'pop', 'post-teen pop']                 94
# 12                ['dance pop', 'pop', 'post-teen pop']                 94
# 13                ['dance pop', 'pop', 'post-teen pop']                 94
# 14                ['dance pop', 'pop', 'post-teen pop']                 94
# 15                ['dance pop', 'pop', 'post-teen pop']                 94
# 16                ['dance pop', 'pop', 'post-teen pop']                 94
# 17                ['dance pop', 'pop', 'post-teen pop']                 94
# 18                ['dance pop', 'pop', 'post-teen pop']                 94
# 19                    ['dwn trap', 'rap', 'trap music']                 97
# 20                    ['dwn trap', 'rap', 'trap music']                 97
# 21                    ['dwn trap', 'rap', 'trap music']                 97
# 22                    ['dwn trap', 'rap', 'trap music']                 97
# 23                    ['dwn trap', 'rap', 'trap music']                 97
# 24                    ['dwn trap', 'rap', 'trap music']                 97
# 25                    ['dwn trap', 'rap', 'trap music']                 97
# 26                    ['dwn trap', 'rap', 'trap music']                 97
# 27                    ['dwn trap', 'rap', 'trap music']                 97
# 28                    ['dwn trap', 'rap', 'trap music']                 97
# 29                    ['dwn trap', 'rap', 'trap music']                 97
# ...                                                 ...                ...
# 9970                                                 []                 53
# 9971                           ['regional mexican pop']                 52
# 9972               ['dance pop', 'k-pop', 'korean pop']                 58
# 9973                           ['regional mexican pop']                 61
# 9974  ['contemporary country', 'country', 'country r...                 78
# 9975  ['bachata', 'latin', 'latin hip hop', 'reggaet...                 62
# 9976                                                 []                 50
# 9977                                                 []                 41
# 9978                                                 []                 43
# 9979  ['emo', 'modern rock', 'pop emo', 'pop punk', ...                 70
# 9980                                                 []                 49
# 9981  ['alternative rock', 'chillwave', 'dance-punk'...                 55
# 9982  ['deep underground hip hop', 'hip hop', 'pop r...                 63
# 9983                                                 []                 66
# 9984  ['album rock', 'art rock', 'classic funk rock'...                 82
# 9985  ['cumbia', 'latin', 'latin pop', 'pop reggaeto...                 73
# 9986                    ['deep indie r&b', 'indie r&b']                 62
# 9987                                                 []                 52
# 9988                    ['deep indie r&b', 'soul flow']                 46
# 9989                                                 []                 42
# 9990  ['big room', 'deep big room', 'deep pop edm', ...                 60
# 9991                                                 []                 44
# 9992  ['hip pop', 'indie r&b', 'neo mellow', 'pop', ...                 81
# 9993         ['deep tropical house', 'indie poptimism']                 56
# 9994                                                 []                 47
# 9995                                                 []                 46
# 9996                                                 []                 46
# 9997                                                 []                 45
# 9998  ['deep underground hip hop', 'gangster rap', '...                 67
# 9999                                                 []                 51
#
#      album_genres  album_popularity album_release_date
# 0              []                90         2017-09-15
# 1              []                81         2017-10-20
# 2              []                74         2017-04-14
# 3              []                74         2017-04-14
# 4              []                74         2017-04-14
# 5              []                74         2017-04-14
# 6              []                74         2017-04-14
# 7              []                74         2017-04-14
# 8              []                74         2017-04-14
# 9              []                61         2017-06-16
# 10             []                54         2017-09-15
# 11             []                94         2017-08-03
# 12             []                82         2017-11-12
# 13             []                77         2017-08-03
# 14             []                78         2017-05-18
# 15             []                58         2017-12-08
# 16             []                57         2017-12-06
# 17             []                44         2017-12-06
# 18             []                73         2017-05-21
# 19             []                90         2017-09-23
# 20             []                90         2017-09-23
# 21             []                90         2017-09-23
# 22             []                90         2017-09-23
# 23             []                90         2017-09-23
# 24             []                90         2017-09-23
# 25             []                90         2017-09-23
# 26             []                90         2017-09-23
# 27             []                90         2017-09-23
# 28             []                90         2017-09-23
# 29             []                90         2017-09-23
# ...           ...               ...                ...
# 9970           []                45         2017-09-29
# 9971           []                57         2017-06-13
# 9972           []                55         2017-01-02
# 9973           []                59         2017-11-10
# 9974           []                57         2017-11-17
# 9975           []                51         2017-04-14
# 9976           []                49         2017-09-22
# 9977           []                46         2017-11-17
# 9978           []                46         2017-07-27
# 9979           []                53         2017-03-17
# 9980           []                45         2017-11-16
# 9981           []                49         2017-01-27
# 9982           []                57         2017-05-19
# 9983           []                45         2017-05-05
# 9984           []                64         2017-09-29
# 9985           []                61         2017-10-27
# 9986           []                52         2017-11-15
# 9987           []                57         2017-11-03
# 9988           []                46         2017-08-10
# 9989           []                47         2017-01-20
# 9990           []                55         2017-04-14
# 9991           []                49         2017-05-18
# 9992           []                58         2017-04-07
# 9993           []                44         2017-09-29
# 9994           []                45         2017-09-08
# 9995           []                50         2017-05-11
# 9996           []                49         2017-06-30
# 9997           []                43         2017-10-05
# 9998           []                55         2017-08-11
# 9999           []                53         2017-10-30
#
# [10000 rows x 33 columns]

# %%
import re
def reduce_genres(gen):
    genre = re.sub("[^a-zA-Z0-9]"," ",gen).lower().split()
    genre = [i for i in genre if i not in set(stopwords.words("english"))]
    mode1 = str(stats.mode(genre)).split('[')[1].split(']')[0]
    return mode1

# %%
df = df.dropna()

# for idx, row in df.iterrows():
#     print(df.loc[idx,'album_release_date'])
#     if  len(df.loc[idx,'album_release_date'].split('-')) < 2:
#         df.drop(idx, inplace=True)
#         print(len(df))

# print()
# print('before drop incomplete month', len(df))
# for idx, ele in enumerate(df['album_release_date']):
#     if  len(ele.split('-')) < 3:
# #     if len(df.loc[idx, 'album_release_date'].split('-')) < 2:
#         df.drop(df.index[idx], inplace=True)
#         print(len(df))
# print('after drop incomplete month', len(df))

df['year'] = [x.split('-')[0] for x in df['album_release_date']]
# df['month'] = [x.split('-')[1] for x in df['album_release_date']]

df = df.drop(['album_genres', 'artist_name'],axis =1)

df['explicit'] = df['explicit'].map( {True: 1, False: 0} ).astype(int) 

z = df['popularity'].quantile(0.8)
df['class'] = df['popularity'].apply(lambda x: 1 if x >= z else 0)

df = df[(df.astype(str)['artist_genres'] != '[]')].reset_index()

df['reduced_genres'] = df['artist_genres'].apply(lambda x: reduce_genres(x))
# Out:
# /Users/Yomancool/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Yomancool/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:250: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
len(df)
# Out:
# 5926

# %%
def bagwords (df):
       
    
#     listname = ['artist_genres', 'album_name', 'song_name', 'year', 'month']
    listname = ['artist_genres', 'album_name', 'song_name', 'year']


    
  
    dicname = {name: [] for name in listname}
    dicname['song_id'] = []
    
    listid = []
    
    dicdf = {}
    vol = {}
    print(df.shape)
 
        
    for name in listname:
        
        for idx in range(df[name].size):
            
            l = df[name][idx]
          
            r = names_to_words(l)
            
            dicname[name].append(r) 
            
      
            
        
        vectorizer = CountVectorizer(analyzer='word',max_features=30)
        feature = vectorizer.fit_transform(dicname[name]).toarray().tolist()
        vol[name] = vectorizer.get_feature_names()
        
        
        dicdf[name] = pd.DataFrame({name: feature}) 
        
        dicdf[name] = dicdf[name][name].apply(pd.Series)
        ### dicdf[name] already lose column tag name, but change into 0 1 2 
        
        l = len(dicdf[name].columns)
        
        dicdf[name].columns = [(name + '_' +vol[name][x]) for x in range(l)]
        
        print('good', name)
     
   
    
    for idx in range(df['song_id'].size):
        sid = df['song_id'][idx]
        listid.append(sid)
       
            
        dicdf['song_id'] = pd.DataFrame({'song_id':listid}) 

        
            
            
        
    result = pd.concat(dicdf.values(), axis =1)
    
    return result

def names_to_words(names):
    words = re.sub("[^a-zA-Z0-9]"," ",names).lower().split()
    
    words = [i for i in words if i not in set(stopwords.words("english"))]
    ## Need join as string for countvectorizer!
    return (" ".join(words))

# %%
df1 = bagwords( df )
# Out:
# (5926, 35)
# good artist_genres
# good album_name
# good song_name
# good year

# %%
df = df.merge(df1, on='song_id', how='outer')

# df.shape
# df

# %%
len(df.columns)
# Out:
# 126

# %%
traindf = df.drop(['Unnamed: 0', 'song_id', 'artist_id','album_id','song_name',
            'album_name','uri', 'type', 'track_href',
            'analysis_url','artist_genres','album_release_date','popularity', 'artist_popularity', 
            'album_popularity','class','index','reduced_genres'],axis=1) 
len(traindf.columns)
# Out:
# 108

# %%
Y = df['class'].values

X = traindf.values  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(C=1.0, penalty='l1')
clf.fit(X_train,Y_train)
Ascores_Train = cross_val_score(clf, X_train, Y_train, cv=5)
Ascores_Test = clf.score(X_test,Y_test)

print ("LogisticRegression L1")
print(Ascores_Train.mean()) 
print(Ascores_Train.std()) 
print(Ascores_Test)
# Out:
# LogisticRegression L1
# 0.792302864662
# 0.0051632223871
# 0.783400809717

# %%
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.cross_validation import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.datasets import make_classification

clf = LogisticRegression(C=1.0, penalty='l1')
# The "accuracy" scoring is proportional to the number of correct
# classifications
rfecv = RFECV(estimator=clf, step=1, cv=StratifiedKFold(Y_train, 2),
              scoring='accuracy')
rfecv.fit(X_train, Y_train)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 68

# %%
# Ascores_Train = cross_val_score(rfecv, X_train, Y_train, cv=5)
Ascores_Test = rfecv.score(X_test,Y_test)

print ("linear regression l1 with feature selection")
# print(Ascores_Train.mean()) 
# print(Ascores_Train.std()) 
print(Ascores_Test)
# Out:
# linear regression l1 with feature selection
# 0.785425101215

# %%
df_new = rfecv.fit_transform(X_train, Y_train)

# %%
importance = []
ranking = []

for i,x in enumerate(rfecv.support_):
    if x == True:
        importance.append(traindf.columns[i])
        
print(importance)
# Out:
# ['explicit', 'disc_number', 'track_number', 'tempo', 'key', 'loudness', 'mode', 'speechiness', 'liveness', 'valence', 'danceability', 'energy', 'time_signature', 'acousticness', 'instrumentalness', 'artist_genres_alternative', 'artist_genres_christian', 'artist_genres_christmas', 'artist_genres_classical', 'artist_genres_contemporary', 'artist_genres_country', 'artist_genres_dance', 'artist_genres_deep', 'artist_genres_dwn', 'artist_genres_edm', 'artist_genres_folk', 'artist_genres_hip', 'artist_genres_hop', 'artist_genres_house', 'artist_genres_indie', 'artist_genres_latin', 'artist_genres_metal', 'artist_genres_modern', 'artist_genres_music', 'artist_genres_neo', 'artist_genres_post', 'artist_genres_rap', 'artist_genres_rock', 'artist_genres_room', 'artist_genres_southern', 'artist_genres_teen', 'artist_genres_trap', 'artist_genres_tropical', 'artist_genres_underground', 'album_name_album', 'album_name_baby', 'album_name_big', 'album_name_christmas', 'album_name_de', 'album_name_deluxe', 'album_name_edition', 'album_name_en', 'album_name_ep', 'album_name_episode', 'album_name_greatest', 'album_name_hits', 'album_name_know', 'album_name_la', 'album_name_life', 'album_name_live', 'album_name_love', 'album_name_remixes', 'album_name_soundtrack', 'album_name_ultimate', 'album_name_vol', 'song_name_acoustic', 'song_name_bad', 'song_name_en', 'song_name_feat', 'song_name_get', 'song_name_go', 'song_name_good', 'song_name_know', 'song_name_la', 'song_name_let', 'song_name_like', 'song_name_love', 'song_name_night', 'song_name_one', 'song_name_remix', 'song_name_time', 'song_name_version']

# %%
# import matplotlib.pyplot as plt
# from sklearn.svm import SVC
# from sklearn.cross_validation import StratifiedKFold
# from sklearn.feature_selection import RFECV

# clf = svm.SVC(kernel = 'linear')
# # The "accuracy" scoring is proportional to the number of correct
# # classifications
# rfecv = RFECV(estimator=clf, step=1, cv=StratifiedKFold(Y_train, 2),
#               scoring='accuracy')
# rfecv.fit(X_train, Y_train)

# print("Optimal number of features : %d" % rfecv.n_features_)

# # Plot number of features VS. cross-validation scores
# plt.figure()
# plt.xlabel("Number of features selected")
# plt.ylabel("Cross validation score (nb of correct classifications)")
# plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
# plt.show()

# %%
# Ascores_Test = rfecv.score(X_test,Y_test)

# print ("svm(linear) with feature selection")
# # print(Ascores_Train.mean()) 
# # print(Ascores_Train.std()) 
# print(Ascores_Test)

# %%
# # Create the RFE object and compute a cross-validated score.
# svc = SVC(kernel="linear")
# # The "accuracy" scoring is proportional to the number of correct
# # classifications
# svc_rfecv = RFECV(estimator=svc, step=1, cv=StratifiedKFold(Y_train, 2),
#               scoring='accuracy')
# svc_rfecv.fit(X_train, Y_train)
